# %%
height = 1.6
weight = 50
bmi = weight / height ** 2

bmi
# Out:
# 19.531249999999996

# %%
type(bmi)
# Out:
# float

# %%
height = "your heigh in US"

type(height)
# Out:
# str

# %%
bad = False

type(bad)
# Out:
# bool

# %%
'ab' + 'cd'
# Out:
# 'abcd'

# %%
fam = ["Ada",1.6,"Bob",1.76,"Cate",1.8]

fam
# Out:
# ['Ada', 1.6, 'Bob', 1.76, 'Cate', 1.8]

# %%
fam[5] #0 indexing
# Out:
# 1.8

# %%
fam[-1] #backward
# Out:
# 1.8

# %%
# slicing
fam[0:3] #[include,exclude]
# Out:
# ['Ada', 1.6, 'Bob']

# %%
#updte
fam[3] = 1.7

fam
# Out:
# ['Ada', 1.6, 'Bob', 1.7, 'Cate', 1.8]

# %%
fam = fam + ["dog",2.0]

#del fam[0]

fam
# Out:
# ['Ada', 1.6, 'Bob', 1.7, 'Cate', 1.8, 'dog', 2.0]

# %%
# point to same list
x = ["a","b","c"]
y = x
y[0] = "haha"

x
# Out:
# ['haha', 'b', 'c']

# %%
# point to diff list
x = ["a","b","c"]
y = list(x)
y = x[:] #means from start to end
y[0] = "kk"

x
# Out:
# ['a', 'b', 'c']

# %%
# Function

grades = [20,26,73,94,37]
max(grades)
best = max(grades)

best
# Out:
# 94

# %%
round(1.566,1)

round(1.77) #auto round to integer
# Out:
# 2

# %%
# List method: functions used to manipulate objects

fam.index("Bob")
fam.count(1.7)
# Out:
# 1

# %%
# str method

string = 'hello world' #str always 1 word
string.capitalize()
string.replace('e','a')
# Out:
# 'hallo world'

# %%
#some method have same name, for diff obj

string.index('e')
fam.index('Ada')
# Out:
# 0

# %%
fam.append('zebra')

fam
# Out:
# ['Ada', 1.6, 'Bob', 1.7, 'Cate', 1.8, 'dog', 2.0, 'zebra']

# %%
import numpy as np

np.array([1,2,3]) #it works bc array is method under np
# Out:
# array([1, 2, 3])

# %%
from numpy import array #to only use this one method
array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
height = np.array([1.7,1.6,1.8,1.75,1.9])
weight = np.array([50,40,56,70,66])
bmi = weight/height ** 2

bmi

#np.array should only contain 1 type, all convert to str
#list + list > list list; np.array + np.array = sum
# Out:
# array([17.30103806, 15.625     , 17.28395062, 22.85714286, 18.28254848])

# %%
#2D array

np2 = np.array([[1,2,3,4,5],
               [8,7,6,5,4]]) #how many [] = # dimension

np2.shape #2 row, 5 col
# Out:
# (2, 5)

# %%
# selecting a value

int(np2[0][2])
int(np2[0,2])
# Out:
# 3

# %%
np2[:,1:3]

np2[1,:]
# Out:
# array([8, 7, 6, 5, 4])

# %%
np.mean(np2[:,0])
#np.medium
#np.corrcoef
#np.std
# Out:
# np.float64(4.5)

# %%
# generate data

height = np.round(np.random.normal(1.6,0.2,10),2)
weight = np.round(np.random.normal(50,5,10),1)

ppl = np.column_stack((height,weight)) #stack function just wants 1 obj thats why (())

ppl
# Out:
# array([[ 2.01, 50.6 ],
#        [ 1.62, 44.6 ],
#        [ 1.64, 48.9 ],
#        [ 1.33, 53.4 ],
#        [ 1.87, 53.2 ],
#        [ 1.74, 58.8 ],
#        [ 1.82, 54.7 ],
#        [ 1.82, 52.6 ],
#        [ 1.67, 45.5 ],
#        [ 1.43, 50.4 ]])

# %%
import matplotlib.pyplot as plt

# %%
year = [2000,2001,2003,2004]
pop = [2.1,2.4,3.2,3.5]

#add more year
year = ['1999'] + year
pop = ['1.9'] + pop

plt.plot(year,pop)
#plt.scatter(year,pop)

plt.xlabel('year')
plt.ylabel('population')
plt.title('world population')
plt.yticks([0,1,2,3],
           ['0B','1B','2B','3B'])

plt.show()

# %%
values = [1,5,2,5,1,5,2,6,2,1,5,2]
plt.hist(values, bins=3)
plt.show()

# %%
#List, by range

pop = [30,26,29,31,41]
country = ['US','China','Japan','Korea','Canada']
idx_US = country.index('US')

idx_US #position in the list
# Out:
# 0

# %%
pop[idx_US]
# Out:
# 30

# %%
#dict, by unique key

world = {'US':30,'China':26,'Japan':29}
world['US']
# Out:
# 30

# %%
world['sealand'] = 0.1 #add/update into to dict
#del(world['sealand'])
world
# Out:
# {'US': 30, 'China': 26, 'Japan': 29, 'sealand': 0.1}

# %%
#pd dataframe

import pandas as pd

world = pd.read_csv('/Users/lilchainyy/workspace/practicing_Dec25/lands.csv', index_col=0)

world
# Out:
#    country  capital        area  population  Unnamed: 5  Unnamed: 6
# US      US       DC  Washington          21         NaN         NaN
# CH   China  Beijing       North          55         NaN         NaN
# CA  Canada  Toronto     Ontario          23         NaN         NaN
# JP   Japan    Tokyo       Kanto          28         NaN         NaN

# %%
world[['capital']]
# Out:
#     capital
# US       DC
# CH  Beijing
# CA  Toronto
# JP    Tokyo

# %%
world[1:3]
# Out:
#    country  capital     area  population  Unnamed: 5  Unnamed: 6
# CH   China  Beijing    North          55         NaN         NaN
# CA  Canada  Toronto  Ontario          23         NaN         NaN

# %%
#label-based, row access
world.loc[["CH","CA"],["area","population"]]
# Out:
#        area  population
# CH    North          55
# CA  Ontario          23

# %%
#col access
world.loc[:,["area",'population']]
# Out:
#           area  population
# US  Washington          21
# CH       North          55
# CA     Ontario          23
# JP       Kanto          28

# %%
# row & col
world.loc[
    ["US","JP"],
    ["country","area"]
]
# Out:
#    country        area
# US      US  Washington
# JP   Japan       Kanto

# %%
#integer position-based
world.iloc[[1]]
# Out:
#    country  capital   area  population  Unnamed: 5  Unnamed: 6
# CH   China  Beijing  North          55         NaN         NaN

# %%
world.iloc[[0,1,2],[0,3]]
# Out:
#    country  population
# US      US          21
# CH   China          55
# CA  Canada          23

# %%
world.iloc[:,[0,3]]
# Out:
#    country  population
# US      US          21
# CH   China          55
# CA  Canada          23
# JP   Japan          28

# %%
bmi = np.round(np.random.normal(20,2,5),1)

bmi > 22
# Out:
# array([False, False, False, False, False])

# %%
#numpy: logical_and/or/not()...

bmi[np.logical_or(bmi>22,bmi<19)]
# Out:
# array([], dtype=float64)

# %%
#if

z = 1

if z % 2 == 0:  #= means assign a value, == means equal
    print("z even")
elif z % 3 == 0:
    print("z odd"),
else:
    print("nah")

# if z=6, never reach % 3
# Out:
# nah

# %%
# pd Dataframe

loaded = world["population"] > 25

loaded
# Out:
# US    False
# CH     True
# CA    False
# JP     True
# Name: population, dtype: bool

# %%
world[loaded] #to use it

world[world["population"]>25]

world[np.logical_and(world["population"]>25,world["population"]<50)]
# Out:
#    country capital   area  population  Unnamed: 5  Unnamed: 6
# JP   Japan   Tokyo  Kanto          28         NaN         NaN

# %%
#While loop: loops over and over again

error = 10

while error > 1:
    error = error/2
    print(error)
# Out:
# 5.0
# 2.5
# 1.25
# 0.625

# %%
#For loop

ID = [23,27,53,26]

for idx, person in enumerate(ID):
    print(str(idx) + ": " + str(person)) #only number, use "str"
# Out:
# 0: 23
# 1: 27
# 2: 53
# 3: 26

# %%
for a in "hello":
    print(a.capitalize())
# Out:
# H
# E
# L
# L
# O

# %%
office = {"A": 50,
          "B": 65,
          "C": 75}

for name,sal in office.items(): #naming dont matter; 1st gets the ppl, 2nd gets the sal
    print(name,str(sal)) 

#items() formats dict into key-val pair
# Out:
# A 50
# B 65
# C 75

# %%
import pandas as pd

for val in world: #val可以直接用的
    print(val)
# Out:
# country
# capital
# area
# population
# Unnamed: 5
# Unnamed: 6

# %%
for a,b in world.iterrows():  #iterate over Dataframe row by row
    print(a) #a: the row index
    print(b) #b: pd series
# Out:
# US
# country               US
# capital               DC
# area          Washington
# population            21
# Unnamed: 5           NaN
# Unnamed: 6           NaN
# Name: US, dtype: object
# CH
# country         China
# capital       Beijing
# area            North
# population         55
# Unnamed: 5        NaN
# Unnamed: 6        NaN
# Name: CH, dtype: object
# CA
# country        Canada
# capital       Toronto
# area          Ontario
# population         23
# Unnamed: 5        NaN
# Unnamed: 6        NaN
# Name: CA, dtype: object
# JP
# country       Japan
# capital       Tokyo
# area          Kanto
# population       28
# Unnamed: 5      NaN
# Unnamed: 6      NaN
# Name: JP, dtype: object

# %%
for a,b in world.iterrows():
    print(a + ": " + b["capital"])
# Out:
# US: DC
# CH: Beijing
# CA: Toronto
# JP: Tokyo

# %%
#apply: apply a function to each element

world['letter count'] = world['area'].apply(len) #for each element in world["country"], call len > python does len(US), len(China)...

world
# Out:
#    country  capital        area  population  Unnamed: 5  Unnamed: 6  \
# US      US       DC  Washington          21         NaN         NaN
# CH   China  Beijing       North          55         NaN         NaN
# CA  Canada  Toronto     Ontario          23         NaN         NaN
# JP   Japan    Tokyo       Kanto          28         NaN         NaN
#
#     letter count
# US            10
# CH             5
# CA             7
# JP             5
